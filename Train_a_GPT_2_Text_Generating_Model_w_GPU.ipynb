# %% [markdown]
# <a href="https://colab.research.google.com/github/jamesramsay100/twitter_bot/blob/reformat_notebook/Train_a_GPT_2_Text_Generating_Model_w_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
import json

# %% [markdown]
# ## GPU
#
# Colaboratory uses either a Nvidia T4 GPU or an Nvidia K80 GPU. The T4 is slightly faster than the old K80 for training GPT-2, and has more memory allowing you to train the larger GPT-2 models and generate more text.
#
# You can verify which GPU is active by running the cell below.

# %%
# !nvidia-smi
# Out:
# Wed Aug 28 17:30:18 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 430.40       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Downloading GPT-2
#
# If you're retraining a model on new text, you need to download the GPT-2 model first.
#
# There are three released sizes of GPT-2:
#
# * `124M` (default): the "small" model, 500MB on disk.
# * `355M`: the "medium" model, 1.5GB on disk.
# * `774M`: the "large" model, cannot currently be finetuned with Colaboratory but can be used to generate text from the pretrained model (see later in Notebook)
# * `1558M`: the "extra large", true model. Will not work if a K80 GPU is attached to the notebook. (like `774M`, it cannot be finetuned).
#
# Larger models have more knowledge, but take longer to finetune and longer to generate text. You can specify which base model to use by changing `model_name` in the cells below.
#
# The next cell downloads it from Google Cloud Storage and saves it in the Colaboratory VM at `/models/<model_name>`.
#
# This model isn't permanently saved in the Colaboratory VM; you'll have to redownload it if you want to retrain it at a later time.

# %%
gpt2.download_gpt2(model_name="355M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 357Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 141Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 508Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:02, 213Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 290Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 249Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 182Mit/s]

# %% [markdown]
# ## Mounting Google Drive
#
# The best way to get input text to-be-trained into the Colaboratory VM, and to get the trained model *out* of Colaboratory, is to route it through Google Drive *first*.
#
# Running this cell (which will only work in Colaboratory) will mount your personal Google Drive in the VM, which later cells can use to get data in/out. (it will ask for an auth code; that auth is not saved anywhere)

# %%
gpt2.mount_gdrive()

# %%
file_name = "tweets_clean.csv"

# %% [markdown]
# If your text file is larger than 10MB, it is recommended to upload that file to Google Drive first, then copy that file from Google Drive to the Colaboratory VM.

# %%
gpt2.copy_file_from_gdrive(file_name)

# %% [markdown]
# ## Finetune GPT-2
#
# The next cell will start the actual finetuning of GPT-2. It creates a persistent TensorFlow session which stores the training config, then runs the training for the specified number of `steps`. (to have the finetuning run indefinitely, set `steps = -1`)
#
# The model checkpoints will be saved in `/checkpoint/run1` by default. The checkpoints are saved every 500 steps (can be changed) and when the cell is stopped.
#
# The training might time out after 4ish hours; make sure you end training and save the results so you don't lose them!
#
# **IMPORTANT NOTE:** If you want to rerun this cell, **restart the VM first** (Runtime -> Restart Runtime). You will need to rerun imports but not recopy files.
#
# Other optional-but-helpful parameters for `gpt2.finetune`:
#
#
# *  **`restore_from`**: Set to `fresh` to start training from the base GPT-2, or set to `latest` to restart training from an existing checkpoint.
# * **`sample_every`**: Number of steps to print example output
# * **`print_every`**: Number of steps to print training progress.
# * **`learning_rate`**:  Learning rate for the training. (default `1e-4`, can lower to `1e-5` if you have <1MB input data)
# *  **`run_name`**: subfolder within `checkpoint` to save the model. This is useful if you want to work with multiple models (will also need to specify  `run_name` when loading the model)
# * **`overwrite`**: Set to `True` if you want to continue finetuning an existing model (w/ `restore_from='latest'`) without creating duplicate copies.

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='355M',
              steps=1000,
              restore_from='fresh',
              run_name='run2',
              print_every=10,
              sample_every=200,
              save_every=500
              )
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0828 17:32:14.662547 140648727385984 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0828 17:32:29.275661 140648727385984 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Loading checkpoint models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:01<00:00,  1.62s/it]
# dataset has 338025 tokens
# Training...
# [10 | 28.15] loss=3.44 avg=3.44
# [20 | 50.13] loss=3.55 avg=3.49
# [30 | 72.59] loss=3.45 avg=3.48
# [40 | 95.62] loss=3.43 avg=3.47
# [50 | 118.93] loss=3.39 avg=3.45
# [60 | 141.92] loss=3.20 avg=3.41
# [70 | 164.80] loss=3.34 avg=3.40
# [80 | 187.81] loss=3.09 avg=3.36
# [90 | 210.93] loss=3.19 avg=3.34
# [100 | 234.04] loss=3.08 avg=3.31
# [110 | 257.12] loss=3.16 avg=3.30
# [120 | 280.17] loss=3.21 avg=3.29
# [130 | 303.24] loss=3.13 avg=3.28
# [140 | 326.38] loss=2.95 avg=3.25
# [150 | 349.52] loss=3.04 avg=3.24
# [160 | 372.62] loss=2.94 avg=3.22
# [170 | 395.74] loss=2.81 avg=3.19
# [180 | 418.86] loss=2.72 avg=3.16
# [190 | 441.92] loss=3.18 avg=3.16
# [200 | 465.01] loss=2.75 avg=3.14
# ======== SAMPLE 1 ========
# .
#
# LUCIO:
# How came your father then to enter in Romeo's house
# In this ancient city?
#
# ROMEO:
# Sir, what a gracious man I was, that I did stay in Romeo's house.
#
# LUCIO:
# O, then, you have no time left, my lord.
#
# ROMEO:
# O, then I pray you, you are lost.
#
# LUCIO:
# I come not, I came not, and that, that.
#
# ROMEO:
# I am lost; come hither,
# And stay not.
#
# LUCIO:
# I, the lord officer, know how you have come.
#
# ROMEO:
# I do know:
# I am a fellow-learned gentleman of Venice:
# As you are, my son, and this is my servant.
#
# LUCIO:
# And is your servant?
#
# ROMEO:
# And your heir?
#
# LUCIO:
# I take your leave:
# Your master and the next of you shall be
# In command.
#
# ROMEO:
# I come too late.
#
# LUCIO:
# Ay, to make the master more certain,
# And to make him better acquainted with me,
# Thou art well acquainted with him; and I
# See how he marries me.
#
# ROMEO:
# I think he will marry you now: he must make a
# Dimonian bride, or he will marry
# The duke: I am content to have it
# In hand. Farewell, fellow-learned gentleman.
#
# ROMEO:
# Now, shall I sit down with you?
#
# GLOUCESTER:
# Your majesty hath issued certain warrant,
# To obtain the marriage of mine son:
# You have been obedient to this demand,
# And you give your report unto your lord,
# When there be some cause to believe,
# You are deceived.
#
# LUCIO:
# What warrant shall he give me for this marriage,
# Where he shall have mine son?
#
# ROMEO:
# The issue of it you have, sir; and the issue
# Of my child: I cannot in conscience consent,
# Or as I may wish, I would consent not.
#
# LUCIO:
# You may in conscience have this issue, sir; or you may
# In conscience have not it;
# Which is all you know, though you may guess.
#
# ROMEO:
# I know, sir:
# I am in haste in this business: the issue hath
# Not been heard of since the marriage of mine
# Son; whose birth date you are certain to believe.
#
# GLOUCESTER:
# You have received the warrant of his lawful power,
# Which must in some say, be for a son: there
# You have been deceived by such a demand,
# And you have been induced to give away
# The duke's warrant, which you have promised.
#
# LUCIO:
# Master, what warrant do I have to procure his marriage?
#
# ROMEO:
# If you entreat in his behalf to forfeit
# Your son's lands; if you entreat in his behalf to
# Purchase his lands:
# If you entreat in his behalf to divorce
# The duke's lands against his will; if you want his
# king for your son's marriage; if you want all your
# rights and rights, your son's lands with him:
# If you have any other demands and
# claims; or some other right, he have sworn
# His allegiance to; your rights and rights with your
# king, have he sworn them to you.
#
# LUCIO:
# You have all that you have: I have not my lands in
# the same trust for you to purchase: and let me rest
# with my master:--
#
# ROMEO:
# This is your master: he hath put forth a demand
# for your son's marriage; and you have bid him
# Take care not to give it to the duke.
#
# LUCIO:
# Tell him of this warrant; and he will forthwith
# Make forth his proceedings: he will answer
# Your petition: he hath here the duke's lands with him,
# And will come to his request in due
# right.
#
# ROMEO:
# This is the warrant of his lawful power; and no warrant
# shall be had, that shall make him accept no other
# course. He is your duke's son,
# And your heir; and to take his son is,
# By the warrant of these good men, a very
# much less duty than to give him over to you.
#
# GLOUCESTER:
# I know you well: if thou wilt not, go to thy master.
#
# BENVOLIO:
# Your majesty will bring forth the warrant, that he may
# With such haste give away
#
# [210 | 499.65] loss=3.01 avg=3.13
# [220 | 522.76] loss=3.03 avg=3.13
# [230 | 545.89] loss=3.02 avg=3.12
# [240 | 569.01] loss=2.93 avg=3.11
# [250 | 592.12] loss=2.83 avg=3.10
# [260 | 615.23] loss=2.60 avg=3.08
# [270 | 638.34] loss=2.68 avg=3.06
# [280 | 661.44] loss=2.66 avg=3.05
# [290 | 684.55] loss=2.70 avg=3.03
# [300 | 707.69] loss=2.35 avg=3.01
# [310 | 730.84] loss=2.72 avg=3.00
# [320 | 753.94] loss=2.46 avg=2.98
# [330 | 777.08] loss=2.52 avg=2.96
# [340 | 800.20] loss=2.51 avg=2.94
# [350 | 823.28] loss=2.79 avg=2.94
# [360 | 846.41] loss=2.50 avg=2.92
# [370 | 869.57] loss=2.31 avg=2.91
# [380 | 892.70] loss=2.32 avg=2.89
# [390 | 915.78] loss=2.18 avg=2.86
# [400 | 938.86] loss=2.37 avg=2.85
# ======== SAMPLE 1 ========
#  deputy then for their son king: and here we stood together, as one body ere I go: the king, this I know, is gone, but it appeared to me he was at length seized: but I perceive we sat on this same side of the law, till we saw his son king come along: so, therefore we stood as one body; and, to make the king fall, we had fear'd this king with all his might, and this with all his might
# and that prince thus he was loath to fall: so, on Elyes' command, this prince presently came along; thus, thus, and thus I with this very body
# plotted him.
#
# LATHAR:
# Ay, to cut thy path so: see how thou cutest it! Why, Elyes, that is the queen, behold this scene now, where she comes up from this pit of thorns,
# which should cleft her to my left and make me writ so.
#
# YORK:
# So I did,
#
# GLOUCESTER:
# And thus did I slip my hand, for that's no good deed in him
# Where he falls, he being king, but that I saw his
# son king come along. Now, in good time, here comes the Lords court: to hear our reasons,
# their words, their desires, their fears, I'll tell you the reason: but I
# think you will think I forgot my purpose, my end; so, in good time,
# here comes the Lords court.
#
# GLOUCESTER:
# Come, lords, this means we have in hand to depose our queen
# And, our lord, our other sons, and all the lords
# And servants of Elyes: let's see what's done,
# ourselves and the nobles of this land be deposed.
#
# YORK:
# This way, and the Tybalt walls
# Away, all away!
#
# ANGELO:
# So have you made all a happy hour by the king's
# Deputation: therefore, good night.
#
# YORK:
# Bold and firm, noble and weak, is a king
# And servant to him, and both his children obey.
#
# ANGELO:
# Nay, 'tis not as if you heard me say,
# 'We must vouch to him' or, if possible,
# 'He must be deposed' or 'The queen' has been wiled 'gainst
# Her all sons. Nay, if 's true' be no more
# Than you, I have heard my lords say, this means we know
# them all well, and
# them both well.
#
# ANGELO:
# Now, as for your lordship,
# Here comes Gremio, a young gentleman: good night.
#
# Gremio:
# Good-night, lords.
#
# ANGELO:
# Well, be gone.
#
# YORK:
# I thank you for your patience.
#
# ANGELO:
# My lord, sir, it is now upon your part
# To undertake your own downfall.
#
# YORK:
# I thank you, good me: it was our will.
#
# ANGELO:
# I thank you as well.
#
# GLOUCESTER:
# I thought the deed so noble and so untoward
# Whereon you will stand us to trial and downfall
# As that which should be yours.
#
# YORK:
# This way, and the Tybalt wallsAway, all away!
#
# ANGELO:
# You shall know, as they say, before a king
# A queen shall be crowned, and she shall not have
# But this crown herself: so, in fair resolution,
# We depose her. Away!
#
# GLOUCESTER:
# Amen.
#
# YORK:
# I see, my lords.
#
# ANGELO:
# Now, as it stands in hand to hand combat,
# No man shall be king: I shall have my revenge,
# In all my deeds before the queen. Best
# happens to a king, what I do shall be revenge
# That I have done. Well, thus it stands: let's see
# What vengeance you do have.
#
# ANGELO:
# I'll name it.
#
# GLOUCESTER:
# You'll find yourself in the wrong,--and that wrong
# Is you, or,--your lordship.
#
# YORK:
# I go
# But for you.
#
# GLOUCESTER:
# You will, in like fashion.
#
# ANGELO:
# Fellow, to such a head!
#
# YORK:
# Fellow, to your heads!
#
# ANGELO:
# Now, to my lord, to the king, to the queen, even to my queen!
# That's
#
# [410 | 972.34] loss=2.09 avg=2.83
# [420 | 995.43] loss=2.24 avg=2.81
# [430 | 1018.60] loss=2.18 avg=2.79
# [440 | 1041.74] loss=2.13 avg=2.77
# [450 | 1064.86] loss=2.24 avg=2.76
# [460 | 1087.95] loss=2.19 avg=2.74
# [470 | 1111.04] loss=2.00 avg=2.72
# [480 | 1134.16] loss=2.23 avg=2.71
# [490 | 1157.30] loss=1.81 avg=2.69
# [500 | 1180.42] loss=2.01 avg=2.67
# Saving checkpoint/run1/model-500
# [510 | 1206.66] loss=1.67 avg=2.65
# [520 | 1229.84] loss=1.72 avg=2.62
# [530 | 1252.97] loss=1.73 avg=2.60
# [540 | 1276.07] loss=1.74 avg=2.58
# [550 | 1299.14] loss=1.64 avg=2.56
# [560 | 1322.26] loss=1.63 avg=2.54
# [570 | 1345.40] loss=1.33 avg=2.51
# [580 | 1368.56] loss=1.49 avg=2.49
# [590 | 1391.70] loss=1.43 avg=2.46
# [600 | 1414.82] loss=1.73 avg=2.45
# ======== SAMPLE 1 ========
# as
# Came in my chamber: I pray you, go on:
# My lord, tell him the queen will be at Berkeley
# To see the fashion in which her daughter should be
# Be wedding-day already: my lord, I know it is
# A very hot day,--
#
# BUCKINGHAM:
# Well, sir, I shall not sleep tonight.
#
# DORSET:
# So, you have worn your brace, your king your protector,
# Your lane valiantly stood between the king's
# Divine and his wrongs: so,--
# Your sallow cheeks have borne the hate of scorn;
# Your eyes, seeing it, have come to terms
# With wrath and despair; so, in doing thus,
# Wine-suck not: for I to your chamber, I
# Pitied myself; looking thus, I did eat,
# And I am satisfied. Now, my liege, if
# Your royal love had not been so, that love should
# Have lived to see this done, I should not
# Had slept tonight, unless Thursday, on your promise
# Of marriage.
#
# Lord Mayor:
# What love is so obtain'd that will not be there?
# Fie, fie! 'tis gone: here is no bed; we'll have to
# consent at will: marry, I know you then.
#
# QUEEN ELIZABETH:
# Ah, wretched fools, thou wert not told when my father died
# That the bed was but a ditch, that now stand'd for shelter:
# Now, fool, now; I am grown worn out of it,
# Ere I can repeat it again and again.
#
# Lord Mayor:
#
# QUEEN ELIZABETH:
# Why then not, my lord, I'll do my duty; for no
# bed hath yet up for hire. What's thou, that takes again?
#
# DORSET:
# I am a gentleman of the Earl of Warwick's blood.
#
# QUEEN ELIZABETH:
# My lord?
#
# Lord Mayor:
# Ah, what a gentleman were so tender
# As Warwick did when he was rayed:
# And now he's withered! O, let me desire to hear
# What thou wilt inform me which of these follies
# Shall be cure by my life. Tell me, Elbow,
# What beauties lie lurking within the hollow clouds,
# That thou mayst accuse that dim alacrity
# Which surrenders me upon their beauties?
# If the cure be but such, I would forget
# Who hath been nor whose life is not. I warrant you,
# O blessed that I may ever have
# More leisure to speak than thou hast. Show
# thy face, fair face; my noble lord; I
# Will not doubt to find thee hence: for I have
# Confound myself lost on the sea; yet I
# Have hear again of sailors that have landed,
# Casting pictures of the dumb wonder of the
# Evening Day; of gentle maids that look with wonder
# When tears are shed for the dead; of tender
# Children that laugh the birds, and cry aloud to them
# When sad stories are told: all these are signs,
# Signs to be ruled by society, to be
# Regrets to be ruled by society: yet these,
# Like to a painting, appear as though painted
# And never as like as the rest. This is my boy: tell me, sir,
# What joy can come from so boundless idle hours
# Of idle time, when no leisure is so spent?
# O, how I might find it when time did stamp me
# Upon the blue-sky side of blessed reverence,
# When I was a little spider in a cloud of dust;
# When all else perished in me a mile above water;
# When, in the summer of pure love winter broke,
# That sunshine which summer so rich in brought down,
# Planted all places where mean summer died,
# Broken all walls of summer's beauty, all walls
# Of summer's beauty's beauty's plain; and what we saw,
# As plainly seen, lay smoothed upon the sun:
# The very observation was lost,
# Which by that loss cannot now come again to us,
# For winter left such marks upon the earth whereof
# This truth was lost.
#
# QUEEN ELIZABETH:
# O, remember that which you have recounted, I mean the sun,
# Or, as he now puts it, the moon, whom
# Her tottering tells the world, as full of age
# As of slow death. The moon hath some leisure
# Within this time, and the heavens with it.
# O, remember too, that, as the time o'erslongs, so
# The hour retires. O, remember too, the time,
# When the goddess, like an eternal day, o'er
#
# [610 | 1448.35] loss=1.45 avg=2.42
# [620 | 1471.38] loss=1.30 avg=2.40
# [630 | 1494.55] loss=1.59 avg=2.38
# [640 | 1517.73] loss=1.47 avg=2.36
# [650 | 1540.81] loss=1.09 avg=2.34
# [660 | 1563.90] loss=1.12 avg=2.31
# [670 | 1587.04] loss=1.07 avg=2.29
# [680 | 1610.18] loss=1.87 avg=2.28
# [690 | 1633.35] loss=0.92 avg=2.25
# [700 | 1656.49] loss=0.88 avg=2.22
# [710 | 1679.59] loss=1.02 avg=2.20
# [720 | 1702.71] loss=1.45 avg=2.19
# [730 | 1725.85] loss=0.92 avg=2.16
# [740 | 1748.97] loss=0.75 avg=2.13
# [750 | 1772.08] loss=1.09 avg=2.11
# [760 | 1795.18] loss=0.69 avg=2.09
# [770 | 1818.27] loss=1.24 avg=2.07
# [780 | 1841.36] loss=0.62 avg=2.05
# [790 | 1864.47] loss=1.07 avg=2.03
# [800 | 1887.61] loss=0.76 avg=2.00
# ======== SAMPLE 1 ========
# ORTION.
#
# CLARENCE:
# Well, I do beseech your highness to pardon me:
# Have pity on me and pray with me.
# What sin have I done to my cousin?
# My actions have had severe penalties;
# My tongue hath leared water with fire:
# My cheek hath smoldered in a bier
# That has not been tongueless forsworn,
# And that flesh and blood has tasted
# The unpardonable sin.
#
# QUEEN:
# O, pardon me those evils that I did
# Inherge upon; those that I slaughter'd:
# Those I kill'd with thorns: O my sweet son
# I now cry amen to their throats;
# And those that I cut have in their graves
# Tabernacles to offer their dear bodies
# For the transgression of this land's cold dead.
#
# YORK:
# Come, York bastard, kill me.
#
# QUEEN:
# O God! did I ever wrong thee?
# I should have kill'd him, I should have.
# Ah, God! did I ever wrong thee?
# What had I done unto him that kill'd him?
# He is a dear friend to me; he hath kill'd me.
# And, O, he is thine enemy to me!
# Alack, poor York! he is a friend to me!
# Why dost thou not turn him from his course?
# What, hast thou not slily cut him off?
# Was he not already a friend to me?
# Was he not already a foe to me?
# Why, now thou hast done enough to him,
# I will kill him with thy halberds.
# Now hath he robbed him of a miserable life;
# And now he is prey to my wish;
# He will be the hen to another,
# If I will go with thee to slaughter him.
# What news abroad?
# Whither will traitors now flock? Where will they flock?
#
# RICHMOND:
# Alack, my lord, tell us. When?
# Will you excuse my death?
#
# EDWARD:
# My cousin, yet what thou speak'st, hear me speak.
#
# RICHMOND:
# Alack, call back the queen.
# Will't be found?
# Will't be bound?
# Go, man, speak.
#
# RICHMOND:
# You lie,--You lie, too, lie!--
#
# PAULIN:
# Ay, but thou art able to stand but to lie.
#
# EDWARD:
# Thy art able to me and to the world;--but thou art
# not tied by me to the strong gaoler.
#
# PAULIN:
# Thy wife and she thou art not bound to,
# Unless thou disdains to go with her to
# The throat of banishment, to be hanged here,
# Before she and she have taken her liberty.
#
# YORK:
# There is but one woman for king, queen,
# And she to have ta'en all.
#
# PAULIN:
# Go, York; be gone, be gone! God save you.
#
# YORK:
# And you say you love her as I do.
#
# RICHMOND:
# I love her as you would wish it did:
# If she have deserved, I know no reason
# Why I should deny her. Go, headstrong, speak.
#
# GLOUCESTER:
# Hark, Oxford!
#
# PAULIN:
# She says you love her as I do.
#
# GLOUCESTER:
# She says you love her as I do.
#
# PAULIN:
# Now, in good time! let them meet; I pray you.
#
# Herald:
# She says you love her as I think you can;
# That's my office, that I will do.
#
# GLOUCESTER:
# Hark ye, Oxford!
#
# OXFORD:
# Prithee, prithee, counsel!
#
# PAULIN:
# She says you love her as I think you can;
# That's my office, that I will do.
#
# OXFORD:
# She says you want a husband;
# Who can vouchsafe to wife with you?
#
# GLOUCESTER:
# She says that she will marry you for nine
# as soon as she can: pray you, sit, then.
#
# OXFORD:
# She says she will not;
# She, she she she she she! so, sit,
# And pray you for speed.
#
# Messenger:
# She says you will not.
#
# Oxford:
# She says she will.
#
# PAULIN:
# She says you will not.
#
# OXFORD:
# She says she will.
#
# Richmond:
# She
#
# [810 | 1921.15] loss=1.07 avg=1.99
# [820 | 1944.24] loss=0.93 avg=1.97
# [830 | 1967.39] loss=0.80 avg=1.95
# [840 | 1990.53] loss=0.72 avg=1.93
# [850 | 2013.68] loss=0.67 avg=1.91
# [860 | 2036.81] loss=0.60 avg=1.88
# [870 | 2059.96] loss=0.51 avg=1.86
# [880 | 2083.06] loss=0.69 avg=1.84
# [890 | 2106.23] loss=0.41 avg=1.82
# [900 | 2129.39] loss=0.63 avg=1.80
# [910 | 2152.49] loss=0.44 avg=1.77
# [920 | 2175.62] loss=0.41 avg=1.75
# [930 | 2198.79] loss=0.44 avg=1.73
# [940 | 2221.91] loss=0.40 avg=1.71
# [950 | 2245.07] loss=0.37 avg=1.68
# [960 | 2268.24] loss=0.40 avg=1.66
# [970 | 2291.40] loss=0.47 avg=1.65
# [980 | 2314.56] loss=0.52 avg=1.63
# [990 | 2337.72] loss=0.47 avg=1.61
# [1000 | 2360.87] loss=0.36 avg=1.59
# Saving checkpoint/run1/model-1000
# W0828 18:11:54.318033 140648727385984 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='run2')

# %% [markdown]
# You're done! Feel free to go to the **Generate Text From The Trained Model** section to generate text based on your retrained model.

# %% [markdown]
# ## Load a Trained Model Checkpoint
#
# Running the next cell will copy the `.rar` checkpoint file from your Google Drive into the Colaboratory VM.

# %%
gpt2.copy_checkpoint_from_gdrive(run_name='run2')

# %% [markdown]
# The next cell will allow you to load the retrained model checkpoint + metadata necessary to generate text.
#
# **IMPORTANT NOTE:** If you want to rerun this cell, **restart the VM first** (Runtime -> Restart Runtime). You will need to rerun imports but not recopy files.

# %%
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='run2')

# %% [markdown]
# ## Generate Text From The Trained Model
#
# After you've trained the model or loaded a retrained model from checkpoint, you can now generate text. `generate` generates a single text from the loaded model.

# %% [markdown]
# If you're creating an API based on your model and need to pass the generated text elsewhere, you can do `text = gpt2.generate(sess, return_as_list=True)[0]`
#
# You can also pass in a `prefix` to the generate function to force the text to start with a given character sequence and generate text from there (good if you add an indicator when the text starts).
#
# You can also generate multiple texts at a time by specifing `nsamples`. Unique to GPT-2, you can pass a `batch_size` to generate multiple samples in parallel, giving a massive speedup (in Colaboratory, set a maximum of 20 for `batch_size`).
#
# Other optional-but-helpful parameters for `gpt2.generate` and friends:
#
# *  **`length`**: Number of tokens to generate (default 1023, the maximum)
# * **`temperature`**: The higher the temperature, the crazier the text (default 0.7, recommended to keep between 0.7 and 1.0)
# * **`top_k`**: Limits the generated guesses to the top *k* guesses (default 0 which disables the behavior; if the generated output is super crazy, you may want to set `top_k=40`)
# * **`top_p`**: Nucleus sampling: limits the generated guesses to a cumulative probability. (gets good results on a dataset with `top_p=0.9`)
# * **`truncate`**: Truncates the input text until a given sequence, excluding that sequence (e.g. if `truncate='<|endoftext|>'`, the returned text will include everything before the first `<|endoftext|>`). It may be useful to combine this with a smaller `length` if the input texts are short.
# *  **`include_prefix`**: If using `truncate` and `include_prefix=False`, the specified `prefix` will not be included in the returned text.

# %% [markdown]
# For bulk generation, you can generate a large amount of text to a file and sort out the samples locally on your computer. The next cell will generate a generated text file with a unique timestamp.
#
# You can rerun the cells as many times as you want for even more generated texts!

# %%
gen_file = 'tweet_preds_raw_output.txt'

gpt2.generate_to_file(sess,
                      run_name='run2',
                      destination_path=gen_file,
                      # length=500,
                      temperature=0.7,
                      nsamples=200,
                      batch_size=5
                      )

# %%
with open(gen_file) as f:
    content = f.readlines()

complete_preds = []
for entry in content:
    if entry.startswith('<|startoftext|>') and entry.endswith('<|endoftext|>'):
        complete_preds.append(entry[len('<|startoftext|>'):-len('<|endoftext|>')])

print(f"Full tweet count : {len(complete_preds)}")

with open('tweet_preds.json', 'w') as outfile:
  json.dump(complete_preds, outfile)
